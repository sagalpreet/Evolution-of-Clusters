# %%
from test import *

# %%
G = get_empty_graph(100)

# %%
af(G)
av(G, 0.3, 0.8)

# %%
th = 0.8

# %%
make_init_connections(G, th)

# %%
nx.draw(G)

# %%
aa(G)

# %%
H = G.copy()

# %%
for i in range(10):
    H = simulate_one_time_step(H, 0.97, 1)
    nx.draw(H, node_size=50)
    plt.show()
    print("-"*50)
# Out:
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
# --------------------------------------------------
